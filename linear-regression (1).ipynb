# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv("../input/mail-customer/Mall_Customers.csv")
df
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1   19                  15                      39
# 1             2   21                  15                      81
# 2             3   20                  16                       6
# 3             4   23                  16                      77
# 4             5   31                  17                      40
# ..          ...  ...                 ...                     ...
# 195         196   35                 120                      79
# 196         197   45                 126                      28
# 197         198   32                 126                      74
# 198         199   32                 137                      18
# 199         200   30                 137                      83
#
# [200 rows x 4 columns]

# %%
x = df.drop("Age",axis=1)
x
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)
# 0             1                  15                      39
# 1             2                  15                      81
# 2             3                  16                       6
# 3             4                  16                      77
# 4             5                  17                      40
# ..          ...                 ...                     ...
# 195         196                 120                      79
# 196         197                 126                      28
# 197         198                 126                      74
# 198         199                 137                      18
# 199         200                 137                      83
#
# [200 rows x 3 columns]

# %%
y = df["Age"]
y
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
from sklearn.model_selection import train_test_split 
train_X, test_X, train_y, test_y = train_test_split(x,y, train_size=0.5, test_size=0.5, random_state=0)
test_X
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)
# 18           19                  23                      29
# 170         171                  87                      13
# 107         108                  63                      46
# 98           99                  61                      42
# 177         178                  88                      69
# ..          ...                 ...                     ...
# 178         179                  93                      14
# 175         176                  88                      86
# 126         127                  71                      35
# 93           94                  60                      40
# 112         113                  64                      42
#
# [100 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
ml = LinearRegression()
ml.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
y_pred = ml.predict( test_X)
print(y_pred )
# Out:
# [38.34616552 43.50412425 37.19665725 37.68859179 34.72090998 43.43270671
#  30.65682778 39.43990005 40.46240485 42.07334904 34.99127777 32.58108937
#  40.69820786 42.73726736 35.95355295 27.83454577 28.62672586 43.45589826
#  31.7076127  36.50204067 31.85727829 29.74079599 33.12633142 33.75979692
#  34.81808378 30.32288602 31.44886588 30.46388278 35.54770773 38.9862138
#  37.35145015 37.10751711 42.5207869  35.9842512  42.22751155 32.45331351
#  32.96296836 36.357945   37.1081956  36.54716775 44.16194094 35.87051445
#  38.01846738 37.28986355 41.25255425 34.39170811 42.30323822 35.40511332
#  37.85820324 31.29295667 37.21941327 40.1873886  39.65783369 36.39740827
#  30.91650082 40.84738276 42.53487409 39.81393548 37.81050897 35.69969278
#  32.99182601 36.85927494 32.13931762 27.40579776 33.19692847 36.48402931
#  36.45802761 30.66210893 34.02663027 34.94866979 33.60345218 35.4959473
#  33.409196   36.78592061 43.22140643 36.90377163 36.90798456 40.80879284
#  33.42870634 30.30487466 35.11019701 34.73504528 43.43246376 33.6052445
#  37.68738158 35.48863546 41.7204697  36.39130663 43.87326825 34.46772812
#  33.73253444 40.58567902 43.59302125 35.03219192 41.75649701 43.50058981
#  31.99304448 39.2702886  37.92734465 37.9104954 ]

# %%
from sklearn.metrics import r2_score
r2_score(test_y,y_pred)
# Out:
# -0.034919379114622284

# %%
plt.scatter(test_y,y_pred)
plt.xlabel('Actual')
plt.ylabel('predicted')
plt.title('Actual vs predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs predicted')
